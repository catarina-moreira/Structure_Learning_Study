# %% [markdown]
# # Gaussian Bayesian Networks

# %%
import rdata
import networkx as nx
import matplotlib.pyplot as plt

# %%
def visualize_bn(model):
    nx_graph = nx.DiGraph()
    nx_graph.add_edges_from(model.edges())
    pos = nx.spring_layout(nx_graph, seed=42)
    nx.draw(nx_graph, pos, with_labels=True, node_size=2000, font_size=14, font_weight='bold')
    plt.show()

# %%
parsed = rdata.parser.parse_file("./ecoli70.rda")
converted = rdata.conversion.convert(parsed)
converted
# Out:
# /Users/pin083/.local/lib/python3.8/site-packages/rdata/conversion/_conversion.py:843: UserWarning: Missing constructor for R class "bn.fit.gnode". The underlying R object is returned instead.
#   warnings.warn(
# /Users/pin083/.local/lib/python3.8/site-packages/rdata/conversion/_conversion.py:843: UserWarning: Missing constructor for R class "bn.fit". The constructor for class "bn.fit.gnet" will be used instead.
#   warnings.warn(
# /Users/pin083/.local/lib/python3.8/site-packages/rdata/conversion/_conversion.py:843: UserWarning: Missing constructor for R class "bn.fit.gnet". The underlying R object is returned instead.
#   warnings.warn(
# {'bn': {'aceB': {'node': ['aceB'],
#    'parents': ['icdA'],
#    'children': [],
#    'coefficients': array([0.13242569, 1.04635758]),
#    'sd': array([0.29211684]),
#    'residuals': array([-0.13242569,  0.13332396, -0.26730127,  0.01088221,  0.66322456,
#           -0.10960194, -0.15671517, -0.02590858, -0.1154781 ]),
#    'fitted.values': array([ 0.13242569, -0.33592396, -1.91309873, -0.95118221, -1.87982456,
#           -2.07559806, -1.72318483, -2.61039142, -2.1032219 ])},
#   'asnA': {'node': ['asnA'],
#    'parents': ['ygcE'],
#    'children': ['icdA', 'lacA', 'lacY', 'lacZ'],
#    'coefficients': array([0.34941501, 0.79745405]),
#    'sd': array([0.30228636]),
#    'residuals': array([-0.34941501,  0.30445376,  0.33767502,  0.24240818,  0.12867064,
#           -0.22528832,  0.12482079, -0.354159  , -0.20916605]),
#    'fitted.values': array([0.34941501, 1.36074624, 1.98132498, 1.85389182, 3.00732936,
#           3.10788832, 1.85157921, 2.766259  , 1.66776605])},
#   'atpD': {'node': ['atpD'],
#    'parents': ['sucA', 'ygcE'],
#    'children': ['yheI'],
#    'coefficients': array([-0.04025017,  0.26029355, -0.72522014]),
#    'sd': array([0.64271108]),
#    'residuals': array([ 0.04025017,  0.25278741,  0.44312677,  0.00610302,  0.09586197,
#            0.29782088,  0.63754248, -0.62258756, -1.15090513]),
#    'fitted.values': array([-0.04025017, -1.04248741, -1.63082677, -1.66960302, -2.94426197,
#           -3.18702088, -2.23374248, -2.33711244, -1.91019487])},
#   'atpG': {'node': ['atpG'],
#    'parents': ['sucA'],
#    'children': [],
#    'coefficients': array([-0.89079139,  0.61799753]),
#    'sd': array([0.62791107]),
#    'residuals': array([ 0.89079139,  0.39429661, -0.65648582, -0.46957169,  0.51939397,
#           -0.04926407,  0.49562014, -0.49510775, -0.62967278]),
#    'fitted.values': array([-0.89079139, -1.08669661, -1.14361418, -1.51082831, -2.04669397,
#           -2.40593593, -2.85522014, -1.12569225, -2.48392722])},
#   'b1191': {'node': ['b1191'],
#    'parents': [],
#    'children': ['fixC', 'tnaA', 'ygcE'],
#    'coefficients': array([1.27298889]),
#    'sd': array([0.78010257]),
#    'residuals': array([-1.27298889, -0.71598889, -0.69148889,  0.06261111,  0.36291111,
#            1.31931111,  0.53661111,  0.11761111,  0.28141111]),
#    'fitted.values': array([1.27298889, 1.27298889, 1.27298889, 1.27298889, 1.27298889,
#           1.27298889, 1.27298889, 1.27298889, 1.27298889])},
#   'b1583': {'node': ['b1583'],
#    'parents': ['lacA', 'lacZ', 'yceP'],
#    'children': [],
#    'coefficients': array([ 1.38195485, -0.24566869,  0.34218049,  0.24070192]),
#    'sd': array([1.05286133]),
#    'residuals': array([-1.38195485, -0.53775593, -0.74252599,  0.27046714,  1.49263482,
#           -0.23510905,  0.37491891,  0.43891023,  0.32041473]),
#    'fitted.values': array([1.38195485, 1.91715593, 2.07302599, 1.67213286, 1.53916518,
#           1.93780905, 1.88068109, 1.85638977, 2.07878527])},
#   'b1963': {'node': ['b1963'],
#    'parents': ['yheI'],
#    'children': [],
#    'coefficients': array([0.96491252, 1.03757535]),
#    'sd': array([0.61387912]),
#    'residuals': array([-0.96491252,  0.11469474, -0.44934469,  0.63535215,  0.57666741,
#            0.12843367,  0.58648148,  0.00122655, -0.62859879]),
#    'fitted.values': array([0.96491252, 0.95090526, 1.76934469, 1.76114785, 2.94533259,
#           2.82476633, 1.42621852, 2.59577345, 3.82249879])},
#   'cchB': {'node': ['cchB'],
#    'parents': ['fixC'],
#    'children': [],
#    'coefficients': array([1.06952272, 0.61798759]),
#    'sd': array([0.80038991]),
#    'residuals': array([-1.06952272, -0.7177729 , -0.16990165, -0.1367747 , -0.04138748,
#            0.14467334, -0.24203301,  0.79700337,  1.43571574]),
#    'fitted.values': array([1.06952272, 1.5288729 , 1.43160165, 2.7437747 , 3.25268748,
#           2.27762666, 2.52933301, 2.08969663, 1.12248426])},
#   'cspA': {'node': ['cspA'],
#    'parents': ['cspG'],
#    'children': ['hupB', 'yfiA'],
#    'coefficients': array([-0.42648533,  0.28871152]),
#    'sd': array([1.23962303]),
#    'residuals': array([ 0.42648533,  1.50856213,  0.39663235,  1.403866  , -0.55018437,
#            0.59615385, -1.35241584, -1.82013105, -0.60896839]),
#    'fitted.values': array([-0.42648533,  0.35323787, -0.26313235,  0.377634  ,  0.28478437,
#            0.33614615,  0.16121584,  0.19433105,  0.40846839])},
#   'cspG': {'node': ['cspG'],
#    'parents': [],
#    'children': ['cspA',
#     'lacA',
#     'lacY',
#     'pspA',
#     'pspB',
#     'yaeM',
#     'yecO',
#     'yedE'],
#    'coefficients': array([2.02607778]),
#    'sd': array([1.03708108]),
#    'residuals': array([-2.02607778,  0.67462222, -1.46027778,  0.75912222,  0.43752222,
#            0.61542222,  0.00952222,  0.12422222,  0.86592222]),
#    'fitted.values': array([2.02607778, 2.02607778, 2.02607778, 2.02607778, 2.02607778,
#           2.02607778, 2.02607778, 2.02607778, 2.02607778])},
#   'dnaG': {'node': ['dnaG'],
#    'parents': ['ycgX', 'yheI'],
#    'children': [],
#    'coefficients': array([0.11701317, 0.59921793, 0.19548024]),
#    'sd': array([0.36082027]),
#    'residuals': array([-0.11701317,  0.21001886, -0.39679545, -0.38569762,  0.15451345,
#           -0.21169807,  0.35126845,  0.46870575, -0.07330218]),
#    'fitted.values': array([1.17013174e-01, 1.78114184e-03, 6.92695452e-01, 3.64397622e-01,
#           1.16418655e+00, 1.82619807e+00, 7.95531548e-01, 1.21709425e+00,
#           2.92570218e+00])},
#   'dnaJ': {'node': ['dnaJ'],
#    'parents': ['sucA'],
#    'children': [],
#    'coefficients': array([ 0.12097704, -0.80848744]),
#    'sd': array([0.75855773]),
#    'residuals': array([-0.12097704, -0.12016756, -0.76262926, -0.63353249,  0.01232805,
#           -0.5346457 ,  0.36768393,  1.59921688,  0.19272319]),
#    'fitted.values': array([0.12097704, 0.37726756, 0.45172926, 0.93213249, 1.63317195,
#           2.1031457 , 2.69091607, 0.42828312, 2.20517681])},
#   'dnaK': {'node': ['dnaK'],
#    'parents': ['yheI'],
#    'children': ['mopB'],
#    'coefficients': array([-0.24693264,  1.0797222 ]),
#    'sd': array([0.53924085]),
#    'residuals': array([ 0.24693264, -0.12059111, -0.70557598, -0.62484618, -0.04303312,
#           -0.0909694 ,  0.63268815,  0.80682528, -0.10143027]),
#    'fitted.values': array([-0.24693264, -0.26150889,  0.59017598,  0.58164618,  1.81393312,
#            1.6884694 ,  0.23311185,  1.45017472,  2.72673027])},
#   'eutG': {'node': ['eutG'],
#    'parents': [],
#    'children': ['ibpB', 'lacY', 'sucA', 'yceP', 'yfaD'],
#    'coefficients': array([1.2654]),
#    'sd': array([0.83135352]),
#    'residuals': array([-1.2654, -0.4792, -0.17  , -0.7149, -0.2568,  1.2639,  0.4352,
#            0.0455,  1.1417]),
#    'fitted.values': array([1.2654, 1.2654, 1.2654, 1.2654, 1.2654, 1.2654, 1.2654, 1.2654,
#           1.2654])},
#   'fixC': {'node': ['fixC'],
#    'parents': ['b1191'],
#    'children': ['cchB', 'tnaA', 'yceP', 'ycgX', 'ygbD', 'yjbO'],
#    'coefficients': array([0.31647563, 0.94060517]),
#    'sd': array([1.06344843]),
#    'residuals': array([-0.31647563, -0.09709271, -0.27753753,  1.13645211,  1.67748838,
#           -0.79990641,  0.34360526,  0.02631883, -1.6928523 ]),
#    'fitted.values': array([0.31647563, 0.84039271, 0.86343753, 1.57274789, 1.85521162,
#           2.75480641, 2.01859474, 1.62448117, 1.7785523 ])},
#   'flgD': {'node': ['flgD'],
#    'parents': ['sucA'],
#    'children': [],
#    'coefficients': array([-0.5166705 ,  0.63619448]),
#    'sd': array([0.62682549]),
#    'residuals': array([ 0.5166705 ,  0.60354415, -0.05836234, -0.00633558,  0.24290865,
#            0.4512285 ,  0.02034188, -1.26331198, -0.50668376]),
#    'fitted.values': array([-0.5166705 , -0.71834415, -0.77693766, -1.15496442, -1.70660865,
#           -2.0764285 , -2.53894188, -0.75848802, -2.15671624])},
#   'folK': {'node': ['folK'],
#    'parents': ['yheI'],
#    'children': [],
#    'coefficients': array([0.56408171, 0.81805283]),
#    'sd': array([0.36666154]),
#    'residuals': array([-0.56408171, -0.117238  , -0.06741807,  0.38264454, -0.25289916,
#            0.05855858,  0.399812  ,  0.41050284, -0.24988102]),
#    'fitted.values': array([0.56408171, 0.553038  , 1.19831807, 1.19185546, 2.12549916,
#           2.03044142, 0.927788  , 1.84989716, 2.81708102])},
#   'ftsJ': {'node': ['ftsJ'],
#    'parents': ['mopB'],
#    'children': [],
#    'coefficients': array([0.67375508, 0.92411862]),
#    'sd': array([0.39547488]),
#    'residuals': array([-0.67375508, -0.01112649,  0.23373925,  0.05890782,  0.37418825,
#           -0.32651359,  0.54095111,  0.01154945, -0.20794073]),
#    'fitted.values': array([ 0.67375508,  0.45732649, -0.52223925,  0.71349218,  2.25261175,
#            2.32931359,  1.82834889,  2.17785055,  2.68094073])},
#   'gltA': {'node': ['gltA'],
#    'parents': ['sucA'],
#    'children': [],
#    'coefficients': array([-0.95721302,  0.37899631]),
#    'sd': array([0.83034676]),
#    'residuals': array([ 0.95721302,  0.52785485,  0.18316041,  0.06796002, -0.28961228,
#            0.43979827,  0.27982859, -1.75073048, -0.41547239]),
#    'fitted.values': array([-0.95721302, -1.07735485, -1.11226041, -1.33746002, -1.66608772,
#           -1.88639827, -2.16192859, -1.10126952, -1.93422761])},
#   'hupB': {'node': ['hupB'],
#    'parents': ['cspA', 'yfiA'],
#    'children': [],
#    'coefficients': array([-0.18205723, -0.29842083,  1.38668711]),
#    'sd': array([0.34037164]),
#    'residuals': array([ 0.18205723,  0.27965924, -0.05508302, -0.12577448, -0.04291777,
#           -0.51777293, -0.1942532 , -0.03209163,  0.50617657]),
#    'fitted.values': array([-0.18205723, -0.33745924, -1.25511698, -0.32292552, -2.85418223,
#           -1.19022707, -3.0234468 , -3.29630837, -2.79367657])},
#   'ibpB': {'node': ['ibpB'],
#    'parents': ['eutG', 'yceP'],
#    'children': [],
#    'coefficients': array([-0.42268134,  1.44714652,  0.12492851]),
#    'sd': array([0.67890903]),
#    'residuals': array([ 0.42268134, -0.46203488, -0.85467494, -0.54483373,  0.44007289,
#           -0.42082434,  0.26287985,  0.92273327,  0.23400053]),
#    'fitted.values': array([-0.42268134,  0.76813488,  1.22457494,  0.37673373,  1.00812711,
#            3.54252434,  2.08792015,  1.61206673,  3.40249947])},
#   'icdA': {'node': ['icdA'],
#    'parents': ['asnA', 'ygcE'],
#    'children': ['aceB'],
#    'coefficients': array([-0.41547914,  0.52283934, -1.05848138]),
#    'sd': array([0.56384646]),
#    'residuals': array([ 0.41547914,  0.43961316, -0.58580899,  0.28078201,  0.38067342,
#            0.45953541, -0.39739915, -0.2590221 , -0.7338529 ]),
#    'fitted.values': array([-0.41547914, -0.88721316, -1.36909101, -1.31638201, -2.30377342,
#           -2.56973541, -1.37600085, -2.3622779 , -1.4027471 ])},
#   'lacA': {'node': ['lacA'],
#    'parents': ['asnA', 'cspG'],
#    'children': ['b1583', 'lacY', 'lacZ', 'yaeM'],
#    'coefficients': array([0.44686994, 0.27239038, 0.25390593]),
#    'sd': array([1.69912285]),
#    'residuals': array([-0.44686994,  3.09162187,  1.07389681,  0.57623933,  0.3825912 ,
#           -0.95245494, -0.73057318, -1.56177668, -1.43267448]),
#    'fitted.values': array([0.44686994, 1.58617813, 1.22220319, 1.72506067, 1.9266088 ,
#           1.90275494, 1.50207318, 1.64987668, 1.57847448])},
#   'lacY': {'node': ['lacY'],
#    'parents': ['asnA', 'cspG', 'eutG', 'lacA'],
#    'children': ['lacZ', 'nuoM'],
#    'coefficients': array([-0.11487507, -0.20397352, -0.22408168,  0.35365485,  1.04620748]),
#    'sd': array([0.24534646]),
#    'residuals': array([ 0.11487507,  0.04681639, -0.07861543,  0.0511528 , -0.11081492,
#            0.33825073, -0.2667255 ,  0.03694542, -0.13188457]),
#    'fitted.values': array([-0.11487507,  4.11228361,  2.07491543,  1.4357472 ,  1.46601492,
#            0.59394927,  0.4344255 , -0.53294542, -0.05661543])},
#   'lacZ': {'node': ['lacZ'],
#    'parents': ['asnA', 'lacA', 'lacY'],
#    'children': ['b1583', 'mopB', 'yaeM'],
#    'coefficients': array([ 0.19996029, -0.01611601,  1.36838439, -0.43756791]),
#    'sd': array([0.58381683]),
#    'residuals': array([-0.19996029, -0.13056372,  0.88768215, -0.17991957, -0.43690169,
#           -0.45627916,  0.58176297,  0.17582479, -0.24164547]),
#    'fitted.values': array([0.19996029, 4.75426372, 2.43101785, 2.66461957, 2.71630169,
#           1.04597916, 1.15043703, 0.49867521, 0.45844547])},
#   'lpdA': {'node': ['lpdA'],
#    'parents': ['yedE'],
#    'children': [],
#    'coefficients': array([-0.10074882,  0.96094769]),
#    'sd': array([0.37403234]),
#    'residuals': array([ 0.10074882,  0.6163796 , -0.46924169,  0.30227403, -0.00477086,
#            0.16246287, -0.09463332, -0.47134947, -0.14186998]),
#    'fitted.values': array([-0.10074882, -1.3081796 , -0.47945831, -1.66757403, -1.26512914,
#           -2.23626287, -2.37396668, -1.95605053, -2.15833002])},
#   'mopB': {'node': ['mopB'],
#    'parents': ['dnaK', 'lacZ'],
#    'children': ['ftsJ'],
#    'coefficients': array([ 0.03568437,  0.89579537, -0.05902883]),
#    'sd': array([0.56023697]),
#    'residuals': array([-0.03568437,  0.34533064, -1.03061061,  0.19268292,  0.22100192,
#            0.35959183,  0.54038574, -0.39007957, -0.2026185 ]),
#    'fitted.values': array([ 0.03568437, -0.57953064, -0.26358939, -0.14968292,  1.48749808,
#            1.43190817,  0.70901426,  2.01767957,  2.3746185 ])},
#   'nmpC': {'node': ['nmpC'],
#    'parents': ['pspA'],
#    'children': [],
#    'coefficients': array([ 0.16881454, -0.76904839]),
#    'sd': array([0.568521]),
#    'residuals': array([-0.16881454,  0.59896449, -0.52134542,  0.88266999,  0.28796983,
#            0.26628631, -0.29401394, -0.65038835, -0.40132837]),
#    'fitted.values': array([ 0.16881454, -0.76296449,  0.33054542, -1.03166999, -0.87016983,
#           -1.15748631, -1.38558606, -1.73181165, -1.47887163])},
#   'nuoM': {'node': ['nuoM'],
#    'parents': ['lacY'],
#    'children': [],
#    'coefficients': array([-2.01756937,  0.40826146]),
#    'sd': array([0.9018575]),
#    'residuals': array([ 2.01756937,  0.48726912, -0.11594299, -0.6733746 , -0.32780657,
#           -0.46801197, -0.61959608, -0.43563294,  0.13552666]),
#    'fitted.values': array([-2.01756937, -0.31956912, -1.20255701, -1.4105254 , -1.46429343,
#           -1.63698803, -1.94910392, -2.22006706, -2.09452666])},
#   'pspA': {'node': ['pspA'],
#    'parents': ['cspG', 'pspB', 'yedE'],
#    'children': ['nmpC'],
#    'coefficients': array([-0.19005095,  0.10792577,  0.13990031, -0.74556915]),
#    'sd': array([0.41515378]),
#    'residuals': array([ 0.19005095, -0.03157178, -0.40780898, -0.02016272,  0.16316752,
#           -0.39525111, -0.07749355,  0.67774825, -0.09867857]),
#    'fitted.values': array([-0.19005095,  1.24317178,  0.19750898,  1.58116272,  1.18783248,
#            2.11985111,  2.09869355,  1.79365175,  2.24117857])},
#   'pspB': {'node': ['pspB'],
#    'parents': ['cspG', 'yedE'],
#    'children': ['pspA'],
#    'coefficients': array([-0.24902567,  0.27586568, -0.98861085]),
#    'sd': array([0.52016569]),
#    'residuals': array([ 0.24902567, -0.27329431, -0.06317067, -0.30874542, -0.13749679,
#           -0.04666342, -0.46868434, -0.02157928,  1.07060856]),
#    'fitted.values': array([-0.24902567,  1.73819431,  0.29667067,  2.13124542,  1.62849679,
#            2.67666342,  2.65118434,  2.25287928,  2.66559144])},
#   'sucA': {'node': ['sucA'],
#    'parents': ['eutG'],
#    'children': ['atpD',
#     'atpG',
#     'dnaJ',
#     'flgD',
#     'gltA',
#     'sucD',
#     'tnaA',
#     'yfaD',
#     'ygcE',
#     'yhdM'],
#    'coefficients': array([ 0.0242884 , -1.08940481]),
#    'sd': array([0.81152502]),
#    'residuals': array([-0.0242884 ,  0.51520166,  0.75994563, -0.42787105, -0.79591471,
#            0.27944318, -1.35034658,  1.02371236,  0.02011791]),
#    'fitted.values': array([ 0.0242884 , -0.83220166, -1.16904563, -0.57542895, -1.07448529,
#           -2.73114318, -1.82835342, -1.40381236, -2.59801791])},
#   'sucD': {'node': ['sucD'],
#    'parents': ['sucA'],
#    'children': [],
#    'coefficients': array([-0.59071525,  0.68299361]),
#    'sd': array([0.66001588]),
#    'residuals': array([ 0.59071525,  0.50702423,  0.17812794, -0.06643726, -0.0230135 ,
#            0.59741069, -0.12125295, -1.40267888, -0.25989552]),
#    'fitted.values': array([-0.59071525, -0.80722423, -0.87012794, -1.27596274, -1.8681865 ,
#           -2.26521069, -2.76174705, -0.85032112, -2.35140448])},
#   'tnaA': {'node': ['tnaA'],
#    'parents': ['b1191', 'fixC', 'sucA'],
#    'children': [],
#    'coefficients': array([-0.38614361, -0.59261336, -0.24419125,  0.11057933]),
#    'sd': array([0.31021847]),
#    'residuals': array([ 0.38614361, -0.00370974, -0.35384206,  0.16194519,  0.02568181,
#            0.26955204, -0.15883617, -0.28312613, -0.04380854]),
#    'fitted.values': array([-0.38614361, -0.93279026, -0.91905794, -1.95014519, -2.42508181,
#           -2.67085204, -2.38686383, -1.65537387, -1.61329146])},
#   'yaeM': {'node': ['yaeM'],
#    'parents': ['cspG', 'lacA', 'lacZ'],
#    'children': [],
#    'coefficients': array([ 0.36651198,  1.47218224, -0.71729449,  0.72038605]),
#    'sd': array([0.81002313]),
#    'residuals': array([-0.36651198, -0.94112336,  0.43896201,  0.19823264,  1.05584833,
#            0.55285193,  0.11695383, -0.6650522 , -0.39016119]),
#    'fitted.values': array([0.36651198, 4.31792336, 1.94323799, 4.60606736, 3.97905167,
#           3.99844807, 4.05774617, 3.9548522 , 4.67566119])},
#   'yceP': {'node': ['yceP'],
#    'parents': ['eutG', 'fixC'],
#    'children': ['b1583', 'ibpB', 'yfaD'],
#    'coefficients': array([-0.12804486,  1.14086752, -0.32674334]),
#    'sd': array([0.40909365]),
#    'residuals': array([ 0.12804486, -0.10123685, -0.43352249,  0.40731036, -0.0987479 ,
#            0.32209922, -0.64338131,  0.27396955,  0.14546457]),
#    'fitted.values': array([-0.12804486,  0.52603685,  0.93022249, -0.38521036, -0.1316521 ,
#            2.11880078,  1.04028131,  0.82813045,  2.59013543])},
#   'ycgX': {'node': ['ycgX'],
#    'parents': ['fixC', 'yheI'],
#    'children': ['dnaG'],
#    'coefficients': array([ 0.15838321, -0.27162389,  1.24483248]),
#    'sd': array([0.50546216]),
#    'residuals': array([-0.15838321, -0.12757993, -0.25655739, -0.21528421, -0.44992924,
#            0.40885211,  0.91709423, -0.34351418,  0.22530182]),
#    'fitted.values': array([ 0.15838321, -0.06032007,  0.96435739,  0.37778421,  1.57482924,
#            1.85874789,  0.07020577,  1.66661418,  3.56349818])},
#   'yecO': {'node': ['yecO'],
#    'parents': ['cspG'],
#    'children': [],
#    'coefficients': array([0.27191682, 0.79486631]),
#    'sd': array([0.47422099]),
#    'residuals': array([-0.27191682, -0.82591225,  0.07104783, -0.21517846,  0.61405055,
#            0.12464383,  0.08935333,  0.58148216, -0.16757018]),
#    'fitted.values': array([0.27191682, 2.41861225, 0.72165217, 2.48577846, 2.23014945,
#           2.37155617, 1.88994667, 1.98111784, 2.57067018])},
#   'yedE': {'node': ['yedE'],
#    'parents': ['cspG'],
#    'children': ['lpdA', 'pspA', 'pspB', 'yheI'],
#    'coefficients': array([-0.16060391, -0.64202673]),
#    'sd': array([0.526442]),
#    'residuals': array([ 0.16060391,  0.6380255 ,  0.12976264,  0.31827676,  0.53060096,
#           -0.36578248, -0.89808648, -0.38954601, -0.12385479]),
#    'fitted.values': array([-0.16060391, -1.8945255 , -0.52386264, -1.94877676, -1.74230096,
#           -1.85651752, -1.46751352, -1.54115399, -2.01734521])},
#   'yfaD': {'node': ['yfaD'],
#    'parents': ['eutG', 'sucA', 'yceP'],
#    'children': [],
#    'coefficients': array([ 0.16282526,  0.28757567, -0.24374099,  0.31777235]),
#    'sd': array([0.43240959]),
#    'residuals': array([-0.16282526, -0.15797283,  0.13481239,  0.41659624,  0.36494753,
#            0.38057931, -0.52467975, -0.36077105, -0.09068657]),
#    'fitted.values': array([0.16282526, 0.60117283, 0.73538761, 0.57270376, 0.83555247,
#           2.26342069, 1.55277975, 0.98267105, 2.35268657])},
#   'yfiA': {'node': ['yfiA'],
#    'parents': ['cspA'],
#    'children': ['hupB'],
#    'coefficients': array([-1.19281955,  0.85722618]),
#    'sd': array([0.56179828]),
#    'residuals': array([ 1.19281955, -0.11456416,  0.33327986, -0.05252889, -0.56377262,
#           -0.13277242, -0.09145262, -0.00920212, -0.5618066 ]),
#    'fitted.values': array([-1.19281955,  0.40316416, -1.07837986,  0.33432889, -1.42032738,
#           -0.39362758, -2.21394738, -2.58649788, -1.3646934 ])},
#   'ygbD': {'node': ['ygbD'],
#    'parents': ['fixC'],
#    'children': [],
#    'coefficients': array([1.35043586, 0.66068811]),
#    'sd': array([0.86024407]),
#    'residuals': array([-1.35043586, -0.29212533, -0.13213302, -0.21997208, -0.15224874,
#            1.05548496, -0.37991331,  0.08710021,  1.38424317]),
#    'fitted.values': array([1.35043586, 1.84152533, 1.73753302, 3.14037208, 3.68444874,
#           2.64201504, 2.91111331, 2.44109979, 1.40705683])},
#   'ygcE': {'node': ['ygcE'],
#    'parents': ['b1191', 'sucA'],
#    'children': ['asnA', 'atpD', 'icdA'],
#    'coefficients': array([0.52395079, 1.88150807, 0.63265346]),
#    'sd': array([0.58561367]),
#    'residuals': array([-0.52395079, -0.10319964,  0.6871708 , -0.51555175,  0.91440519,
#           -0.39120767, -0.03401224,  0.13079567, -0.16444958]),
#    'fitted.values': array([0.52395079, 1.37139964, 1.3592292 , 2.40215175, 2.41859481,
#           3.85030767, 1.91771224, 2.89990433, 1.81764958])},
#   'yhdM': {'node': ['yhdM'],
#    'parents': ['sucA'],
#    'children': [],
#    'coefficients': array([ 0.20849797, -0.77702354]),
#    'sd': array([0.76691675]),
#    'residuals': array([-0.20849797, -0.41371443, -0.4885783 , -0.53008568,  0.36515721,
#           -0.19042657, -0.79852268,  1.20715538,  1.05751306]),
#    'fitted.values': array([0.20849797, 0.45481443, 0.5263783 , 0.98808568, 1.66184279,
#           2.11352657, 2.67842268, 0.50384462, 2.21158694])},
#   'yheI': {'node': ['yheI'],
#    'parents': ['atpD', 'yedE'],
#    'children': ['b1963', 'dnaG', 'dnaK', 'folK', 'ycgX'],
#    'coefficients': array([-0.21374433, -0.96332282,  0.33815017]),
#    'sd': array([0.37499677]),
#    'residuals': array([ 0.21374433, -0.13560601, -0.0218292 , -0.06998932, -0.21174782,
#           -0.02551682, -0.0793835 , -0.41273567,  0.74306401]),
#    'fitted.values': array([-0.21374433,  0.12210601,  0.7971292 ,  0.83738932,  2.12044782,
#            1.81801682,  0.5239835 ,  1.98453567,  2.01103599])},
#   'yjbO': {'node': ['yjbO'],
#    'parents': ['fixC'],
#    'children': [],
#    'coefficients': array([ 1.59101726, -0.07064048]),
#    'sd': array([1.36058911]),
#    'residuals': array([-1.59101726, -1.24071019, -0.807529  , -0.45953807, -0.38276564,
#            0.32197781,  0.45164968,  1.26409604,  2.44383663]),
#    'fitted.values': array([1.59101726, 1.53851019, 1.549629  , 1.39963807, 1.34146564,
#           1.45292219, 1.42415032, 1.47440396, 1.58496337])}}}

# %%
import pyAgrum.lib.notebook as gnb
import pyAgrum as gum

# %%
import numpy as np
from pgmpy.models import LinearGaussianBayesianNetwork
from pgmpy.factors.continuous import LinearGaussianCPD

# %%
nodes_data = {
    'aceB': {
        'node': ['aceB'],
        'parents': ['icdA'],
        'coefficients': np.array([0.13242569, 1.04635758]),
        'sd': np.array([0.29211684]),
    },
    'asnA': {
        'node': ['asnA'],
        'parents': ['ygcE'],
        'children': ['icdA', 'lacA', 'lacY', 'lacZ'],
        'coefficients': np.array([0.34941501, 0.79745405]),
        'sd': np.array([0.30228636]),
    }
}

# %%
#Create an empty Linear Gaussian Bayesian Network
model = LinearGaussianBayesianNetwork()

# Add nodes and edges
for node_data in nodes_data.values():
    node = node_data['node'][0]
    parents = node_data['parents']
    
    # Add the node to the model
    model.add_node(node)
    
    # Add edges from parents to the node
    for parent in parents:
        model.add_edge(parent, node)

# Add CPDs (Conditional Probability Distributions) for each node
for node_data in nodes_data.values():
    node = node_data['node'][0]
    parents = node_data['parents']
    coefficients = node_data['coefficients']
    sd = node_data['sd'][0]
    
    cpd = LinearGaussianCPD(node, coefficients, sd, parents)
    model.add_cpds(cpd)

# Check if the model is consistent
print("Model is consistent: ", model.check_model())

# Print model summary
print("\nModel Summary:")
print(model)
# Out:
# Model is consistent:  True
#
# Model Summary:

# %%
visualize_bn(model)

# %%
parents = converted_bn[node]['parents']
children = converted_bn[node]['children']
mu = converted_bn[node]['coefficients']
sd = converted_bn[node]['sd']
# Out:
# ['icdA']

# %%
bn
# Out:
# (pyAgrum.BayesNet<double>@0x7f90aa88ea00) BN{nodes: 0, arcs: 0, domainSize: 1, dim: 0, mem: 0o}
